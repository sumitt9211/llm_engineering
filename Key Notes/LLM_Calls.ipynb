# %%
# imports

import os
from dotenv import load_dotenv
from IPython.display import Markdown, display, update_display

import google.generativeai
from openai import OpenAI
import anthropic

# %%
load_dotenv(r"C:\Users\Dell\Desktop\.env", override = True)

openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')

# %%
openai = OpenAI()
claude = anthropic.Anthropic()
google.generativeai.configure()

# %%
system_message = "You are an assistant that is great at telling jokes"
user_prompt = "Tell a light-hearted joke for an audience of Data Scientists"

# %%
prompts = [
    {"role": "system", "content": system_message},
    {"role": "user", "content": user_prompt}
  ]

# %%
# GPT-4o-mini
# Temperature setting controls creativity

completion = openai.chat.completions.create(
    model='gpt-4o-mini',
    messages=prompts,
    temperature=0.7
)
print(completion.choices[0].message.content)
# Out:
# Why did the data scientist break up with the statistician?
#
# Because she found him too mean!

# %%
# Have it stream back results in markdown

stream = openai.chat.completions.create(
    model='gpt-4o-mini',
    messages=prompts,
    temperature=0.7,
    stream=True
)

reply = ""
display_handle = display(Markdown(""), display_id=True)
for chunk in stream:
    reply += chunk.choices[0].delta.content or ''
    reply = reply.replace("```","").replace("markdown","")
    update_display(Markdown(reply), display_id=display_handle.display_id)
# Out:
# Why did the data scientist bring a ladder to work?
#
# Because they wanted to reach new heights in their analysis!

# %%
# Claude 3.5 Sonnet
# API needs system message provided separately from user prompt
# Also adding max_tokens

message = claude.messages.create(
    model="claude-3-5-sonnet-20240620",
    max_tokens=200,
    temperature=0.7,
    system=system_message,
    messages=[
        {"role": "user", "content": user_prompt},
    ],
)

print(message.content[0].text)
# Out:
# Sure, here's a light-hearted joke for data scientists:
#
# Why did the data scientist break up with their significant other?
#
# There was just too much noise in the relationship, and not enough signal!
#
# This joke plays on the concept of signal-to-noise ratio, which is important in data analysis. Data scientists often work to separate meaningful information (signal) from irrelevant or random data (noise). The joke humorously applies this concept to a personal relationship, suggesting that there wasn't enough meaningful interaction (signal) compared to the distractions or conflicts (noise).

# %%
# Claude 3.5 Sonnet again
# Now let's add in streaming back results

result = claude.messages.stream(
    model="claude-3-5-sonnet-20240620",
    max_tokens=200,
    temperature=0.7,
    system=system_message,
    messages=[
        {"role": "user", "content": user_prompt},
    ],
)

with result as stream:
    for text in stream.text_stream:
            print(text, end="", flush=True)
# Out:
# Sure, here's a light-hearted joke for data scientists:
#
#  significant other?ientist break up with their
#
#  relationship, and they couldn't find a way to normalize it!
#
# Ba dum tss! 🥁
#
#  plays on statistical concepts like variance and normalization, which data scientists work with regularly. It's a bit nerdy, but should get a chuckle from those in the field!

# %%
# The API for Gemini has a slightly different structure.
# I've heard that on some PCs, this Gemini code causes the Kernel to crash.
# If that happens to you, please skip this cell and use the next cell instead - an alternative approach.

gemini = google.generativeai.GenerativeModel(
    model_name='gemini-1.5-flash',
    system_instruction=system_message
)
response = gemini.generate_content(user_prompt)
print(response.text)
# Out:
# Why was the data scientist sad?  Because they didn't get any arrays!

# %%
# As an alternative way to use Gemini that bypasses Google's python API library,
# Google has recently released new endpoints that means you can use Gemini via the client libraries for OpenAI!

gemini_via_openai_client = OpenAI(
    api_key=google_api_key, 
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/"
)

response = gemini_via_openai_client.chat.completions.create(
    model="gemini-1.5-flash",
    messages=prompts
)
print(response.choices[0].message.content)
# Out:
# Why was the Data Scientist sad?  Because they didn't get any arrays.
